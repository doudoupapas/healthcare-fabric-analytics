# %% [markdown]
# **REST API CALL: HealthData.gov public API**

# %%
import requests
from pyspark.sql import Row
import json

# Public CDC hospital admissions dataset (no API key needed)
url = "https://data.cdc.gov/resource/aemt-mg7g.json"
params = {"$limit": 1000}

response = requests.get(url, params=params)
data = response.json()

print(f"Records fetched: {len(data)}")
print("Sample record:", json.dumps(data[0], indent=2))
# Out:
# StatementMeta(, 06ee966e-71e3-4ac3-ba16-06d5d706df02, 3, Finished, Available, Finished, False)
# Records fetched: 1000
# Sample record: {
#   "week_end_date": "2021-01-16T00:00:00.000",
#   "jurisdiction": "AS",
#   "weekly_actual_days_reporting_any_data": "0",
#   "weekly_percent_days_reporting_any_data": "0.0",
#   "num_hospitals_previous_day_admission_adult_covid_confirmed": "0",
#   "num_hospitals_previous_day_admission_pediatric_covid_confirmed": "0",
#   "num_hospitals_previous_day_admission_influenza_confirmed": "0",
#   "num_hospitals_total_patients_hospitalized_confirmed_influenza": "0",
#   "num_hospitals_icu_patients_confirmed_influenza": "0",
#   "num_hospitals_inpatient_beds": "0",
#   "num_hospitals_total_icu_beds": "0",
#   "num_hospitals_inpatient_beds_used": "0",
#   "num_hospitals_icu_beds_used": "0",
#   "num_hospitals_percent_inpatient_beds_occupied": "0",
#   "num_hospitals_percent_staff_icu_beds_occupied": "0",
#   "num_hospitals_percent_inpatient_beds_covid": "0",
#   "num_hospitals_percent_inpatient_beds_influenza": "0",
#   "num_hospitals_percent_staff_icu_beds_covid": "0",
#   "num_hospitals_percent_icu_beds_influenza": "0",
#   "num_hospitals_admissions_all_covid_confirmed": "0",
#   "num_hospitals_total_patients_hospitalized_covid_confirmed": "0",
#   "num_hospitals_staff_icu_patients_covid_confirmed": "0",
#   "percent_hospitals_previous_day_admission_adult_covid_confirmed": "0.0",
#   "percent_hospitals_previous_day_admission_pediatric_covid_confirmed": "0.0",
#   "percent_hospitals_previous_day_admission_influenza_confirmed": "0.0",
#   "percent_hospitals_total_patients_hospitalized_confirmed_influenza": "0.0",
#   "percent_hospitals_icu_patients_confirmed_influenza": "0.0",
#   "percent_hospitals_inpatient_beds": "0.0",
#   "percent_hospitals_total_icu_beds": "0.0",
#   "percent_hospitals_inpatient_beds_used": "0.0",
#   "percent_hospitals_icu_beds_used": "0.0",
#   "percent_hospitals_percent_inpatient_beds_occupied": "0.0",
#   "percent_hospitals_percent_staff_icu_beds_occupied": "0.0",
#   "percent_hospitals_percent_inpatient_beds_covid": "0.0",
#   "percent_hospitals_percent_inpatient_beds_influenza": "0.0",
#   "percent_hospitals_percent_staff_icu_beds_covid": "0.0",
#   "percent_hospitals_percent_icu_beds_influenza": "0.0",
#   "percent_hospitals_admissions_all_covid_confirmed": "0.0",
#   "percent_hospitals_total_patients_hospitalized_covid_confirmed": "0.0",
#   "percent_hospitals_staff_icu_patients_covid_confirmed": "0.0",
#   "abs_chg_percent_hospitals_previous_day_admission_adult_covid_confirmed": "0.0",
#   "abs_chg_percent_hospitals_previous_day_admission_pediatric_covid_confirmed": "0.0",
#   "abs_chg_percent_hospitals_previous_day_admission_influenza_confirmed": "0.0",
#   "abs_chg_percent_hospitals_total_patients_hospitalized_confirmed_influenza": "0.0",
#   "abs_chg_percent_hospitals_icu_patients_confirmed_influenza": "0.0",
#   "abs_chg_percent_hospitals_inpatient_beds": "0.0",
#   "abs_chg_percent_hospitals_total_icu_beds": "0.0",
#   "abs_chg_percent_hospitals_inpatient_beds_used": "0.0",
#   "abs_chg_percent_hospitals_icu_beds_used": "0.0",
#   "abs_chg_percent_hospitals_percent_inpatient_beds_occupied": "0.0",
#   "abs_chg_percent_hospitals_percent_staff_icu_beds_occupied": "0.0",
#   "abs_chg_percent_hospitals_percent_inpatient_beds_covid": "0.0",
#   "abs_chg_percent_hospitals_percent_inpatient_beds_influenza": "0.0",
#   "abs_chg_percent_hospitals_percent_staff_icu_beds_covid": "0.0",
#   "abs_chg_percent_hospitals_percent_icu_beds_influenza": "0.0",
#   "abs_chg_percent_hospitals_admissions_all_covid_confirmed": "0.0",
#   "abs_chg_percent_hospitals_total_patients_hospitalized_covid_confirmed": "0.0",
#   "abs_chg_percent_hospitals_staff_icu_patients_covid_confirmed": "0.0"
# }

# %% [markdown]
# #### **Convert JSON response to Spark DataFrame**

# %%
from pyspark.sql.types import StructType
from pyspark.sql import functions as F

# Convert JSON response to Spark DataFrame
df_api = spark.createDataFrame(data)

# Preview
display(df_api.limit(5))
print(f"Columns: {df_api.columns}")
# Out:
# StatementMeta(, 06ee966e-71e3-4ac3-ba16-06d5d706df02, 4, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, 99be0672-29ad-4384-b2bc-b01bb985c746)
# Columns: ['abs_chg_percent_hospitals_admissions_all_covid_confirmed', 'abs_chg_percent_hospitals_icu_beds_used', 'abs_chg_percent_hospitals_icu_patients_confirmed_influenza', 'abs_chg_percent_hospitals_inpatient_beds', 'abs_chg_percent_hospitals_inpatient_beds_used', 'abs_chg_percent_hospitals_percent_icu_beds_influenza', 'abs_chg_percent_hospitals_percent_inpatient_beds_covid', 'abs_chg_percent_hospitals_percent_inpatient_beds_influenza', 'abs_chg_percent_hospitals_percent_inpatient_beds_occupied', 'abs_chg_percent_hospitals_percent_staff_icu_beds_covid', 'abs_chg_percent_hospitals_percent_staff_icu_beds_occupied', 'abs_chg_percent_hospitals_previous_day_admission_adult_covid_confirmed', 'abs_chg_percent_hospitals_previous_day_admission_influenza_confirmed', 'abs_chg_percent_hospitals_previous_day_admission_pediatric_covid_confirmed', 'abs_chg_percent_hospitals_staff_icu_patients_covid_confirmed', 'abs_chg_percent_hospitals_total_icu_beds', 'abs_chg_percent_hospitals_total_patients_hospitalized_confirmed_influenza', 'abs_chg_percent_hospitals_total_patients_hospitalized_covid_confirmed', 'jurisdiction', 'num_hospitals_admissions_all_covid_confirmed', 'num_hospitals_icu_beds_used', 'num_hospitals_icu_patients_confirmed_influenza', 'num_hospitals_inpatient_beds', 'num_hospitals_inpatient_beds_used', 'num_hospitals_percent_icu_beds_influenza', 'num_hospitals_percent_inpatient_beds_covid', 'num_hospitals_percent_inpatient_beds_influenza', 'num_hospitals_percent_inpatient_beds_occupied', 'num_hospitals_percent_staff_icu_beds_covid', 'num_hospitals_percent_staff_icu_beds_occupied', 'num_hospitals_previous_day_admission_adult_covid_confirmed', 'num_hospitals_previous_day_admission_influenza_confirmed', 'num_hospitals_previous_day_admission_pediatric_covid_confirmed', 'num_hospitals_staff_icu_patients_covid_confirmed', 'num_hospitals_total_icu_beds', 'num_hospitals_total_patients_hospitalized_confirmed_influenza', 'num_hospitals_total_patients_hospitalized_covid_confirmed', 'percent_hospitals_admissions_all_covid_confirmed', 'percent_hospitals_icu_beds_used', 'percent_hospitals_icu_patients_confirmed_influenza', 'percent_hospitals_inpatient_beds', 'percent_hospitals_inpatient_beds_used', 'percent_hospitals_percent_icu_beds_influenza', 'percent_hospitals_percent_inpatient_beds_covid', 'percent_hospitals_percent_inpatient_beds_influenza', 'percent_hospitals_percent_inpatient_beds_occupied', 'percent_hospitals_percent_staff_icu_beds_covid', 'percent_hospitals_percent_staff_icu_beds_occupied', 'percent_hospitals_previous_day_admission_adult_covid_confirmed', 'percent_hospitals_previous_day_admission_influenza_confirmed', 'percent_hospitals_previous_day_admission_pediatric_covid_confirmed', 'percent_hospitals_staff_icu_patients_covid_confirmed', 'percent_hospitals_total_icu_beds', 'percent_hospitals_total_patients_hospitalized_confirmed_influenza', 'percent_hospitals_total_patients_hospitalized_covid_confirmed', 'week_end_date', 'weekly_actual_days_reporting_any_data', 'weekly_percent_days_reporting_any_data', 'avg_admissions_adult_covid_confirmed', 'avg_admissions_all_covid_confirmed', 'avg_admissions_pediatric_covid_confirmed', 'avg_icu_beds_used', 'avg_inpatient_beds', 'avg_inpatient_beds_used', 'avg_percent_inpatient_beds_covid', 'avg_percent_inpatient_beds_occupied', 'avg_percent_staff_icu_beds_covid', 'avg_percent_staff_icu_beds_occupied', 'avg_staff_icu_patients_covid_confirmed', 'avg_total_icu_beds', 'avg_total_patients_hospitalized_covid_confirmed', 'percent_adult_covid_admissions', 'percent_pediatric_covid_admissions', 'total_admissions_adult_covid_confirmed', 'total_admissions_all_covid_confirmed', 'total_admissions_pediatric_covid_confirmed', 'avg_admissions_all_influenza_confirmed', 'avg_icu_patients_influenza_confirmed', 'avg_percent_icu_beds_influenza', 'avg_percent_inpatient_beds_influenza', 'avg_total_patients_hospitalized_influenza_confirmed', 'total_admissions_all_influenza_confirmed']

# %% [markdown]
# #### **Save raw API response to Bronze**

# %%
# Save raw API response to Bronze
df_api.write.format("delta").mode("overwrite").saveAsTable("bronze_admissions")
print("✅ bronze_admissions saved")
# Out:
# StatementMeta(, 06ee966e-71e3-4ac3-ba16-06d5d706df02, 5, Finished, Available, Finished, False)
# ✅ bronze_admissions saved
